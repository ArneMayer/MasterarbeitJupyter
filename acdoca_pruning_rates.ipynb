# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('results/acdoca_results_100K.csv')

fig, ax = plt.subplots()
plt.hist(df["pruning_rate"], bins=10)
plt.xlabel("Pruning Rate")
plt.ylabel("Number of Columns")
ax.yaxis.grid()
ax.set_axisbelow(True)
plt.show()
